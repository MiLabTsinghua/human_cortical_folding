# %%
from gimmemotifs.motif import Motif,read_motifs
import os
import pandas as pd
from gimmemotifs.motif import default_motifs
os.chdir('/home/gaojie/workspace/Mida_collab/')

# %%
selected_motifs = ['GM.5.0.Sox.0013', ##LEF1
                     'GM.5.0.SMAD.0003', ##NFIC
                     'GM.5.0.SMAD.0004', ##NFIX
                     'GM.5.0.C2H2_ZF.0313', ##MAZ
                     'GM.5.0.Homeodomain.0145', ##MEIS1
                     'GM.5.0.Homeodomain_POU.0016' ##POU3F2
                  ]

# %%
motifs = default_motifs()

# %%
motif_dict = {str(i).rsplit('_', 1)[0]:i for i in motifs}

# %%
motif_dict
# Out:
# {'GM.5.0.Sox.0001': GM.5.0.Sox.0001_AACAAT,
#  'GM.5.0.Homeodomain.0001': GM.5.0.Homeodomain.0001_AGCTGTCAnnA,
#  'GM.5.0.Mixed.0001': GM.5.0.Mixed.0001_snnGGsssGGs,
#  'GM.5.0.Nuclear_receptor.0001': GM.5.0.Nuclear_receptor.0001_TAwsTrGGTCAsTrGGTCA,
#  'GM.5.0.Mixed.0002': GM.5.0.Mixed.0002_GCTAATTA,
#  'GM.5.0.Nuclear_receptor.0002': GM.5.0.Nuclear_receptor.0002_wnyrCTTCCGGGkC,
#  'GM.5.0.bHLH.0001': GM.5.0.bHLH.0001_ACGTG,
#  'GM.5.0.Myb_SANT.0001': GM.5.0.Myb_SANT.0001_rrCCGTTAAACnGyy,
#  'GM.5.0.C2H2_ZF.0001': GM.5.0.C2H2_ZF.0001_GCGkGGGCGG,
#  'GM.5.0.GATA.0001': GM.5.0.GATA.0001_TTATCTsnnnnnnnCA,
#  'GM.5.0.C2H2_ZF.0002': GM.5.0.C2H2_ZF.0002_GGnnCAGGTGnG,
#  'GM.5.0.bZIP.0001': GM.5.0.bZIP.0001_CAGCCAATsAG,
#  'GM.5.0.Homeodomain.0002': GM.5.0.Homeodomain.0002_TAATTr,
#  'GM.5.0.Ets.0001': GM.5.0.Ets.0001_GGAAGT,
#  'GM.5.0.bZIP.0002': GM.5.0.bZIP.0002_TGACkyA,
#  'GM.5.0.IRF.0001': GM.5.0.IRF.0001_GGAAAGyGAAAs,
#  'GM.5.0.bHLH.0002': GM.5.0.bHLH.0002_nGnCAGrTGny,
# ...

# %%
for motif in selected_motifs:
    motif_dict[motif].plot_logo(f'ChromVar/{motif}.pdf')
# Out:
# in validate_matrix(): Row sums in df are not close to 1. Reormalizing rows...
# in validate_matrix(): Row sums in df are not close to 1. Reormalizing rows...
# in validate_matrix(): Row sums in df are not close to 1. Reormalizing rows...
# in validate_matrix(): Row sums in df are not close to 1. Reormalizing rows...
# in validate_matrix(): Row sums in df are not close to 1. Reormalizing rows...
# in validate_matrix(): Row sums in df are not close to 1. Reormalizing rows...
# in validate_matrix(): Row sums in df are not close to 1. Reormalizing rows...
# in validate_matrix(): Row sums in df are not close to 1. Reormalizing rows...
# in validate_matrix(): Row sums in df are not close to 1. Reormalizing rows...
# in validate_matrix(): Row sums in df are not close to 1. Reormalizing rows...
# in validate_matrix(): Row sums in df are not close to 1. Reormalizing rows...
# in validate_matrix(): Row sums in df are not close to 1. Reormalizing rows...
